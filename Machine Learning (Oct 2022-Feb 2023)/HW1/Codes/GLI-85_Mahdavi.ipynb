# %% [markdown]
# # GLI-85

# %% [raw]
# Convert .mat file to .csv file

# %%
# I manually deleted the first row and column of the data frame, which included the row and column numbers, from the .csv generated file.

# %%
from scipy.io import loadmat
import pandas as pd
data = loadmat(r"C:\Bahar\M.Sc Data Mining\Machine Learning (Oct 2022-Feb 2023)\HW1\Data\GLI-85.mat")
print (data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'Y', 'geneSym', 'X', 'geneID'])

# %%
from scipy.io import loadmat
import pandas as pd
data = loadmat(r"C:\Bahar\M.Sc Data Mining\Machine Learning (Oct 2022-Feb 2023)\HW1\Data\GLI-85.mat")
x = data["X"]
df = pd.DataFrame(x)
df.to_csv(r"C:\Bahar\M.Sc Data Mining\Machine Learning (Oct 2022-Feb 2023)\HW1\Data\GLI-85_data.csv")

# %%
from scipy.io import loadmat
import pandas as pd
data = loadmat(r"C:\Bahar\M.Sc Data Mining\Machine Learning (Oct 2022-Feb 2023)\HW1\Data\GLI-85.mat")
x = data["Y"]
df = pd.DataFrame(x)
df.to_csv(r"C:\Bahar\M.Sc Data Mining\Machine Learning (Oct 2022-Feb 2023)\HW1\Data\GLI-85_target.csv")

# %% [raw]
# Import dataset

# %%
import pandas as pd 
X = pd.read_csv(r"C:\Bahar\M.Sc Data Mining\Machine Learning (Oct 2022-Feb 2023)\HW1\Data\GLI-85_data.csv", header=None)
X
# Out:
#         0         1         2         3        4         5         6      \
# 0   29844.273  1011.659   689.391  5198.424  269.881  2033.805   986.082
# 1   17265.617   793.230   584.338  4367.415  538.245  1342.165  1087.825
# 2   25947.941   880.637   862.301  4867.595  294.926  1036.071   979.293
# 3   29054.473  1000.799   842.576  6974.653  428.498  1890.961  1055.917
# 4   30286.408   687.285   798.224  8020.007  404.549  2420.757  1398.942
# ..        ...       ...       ...       ...      ...       ...       ...
# 80  56412.902   958.140   925.398  6217.968  706.057  2690.211  1202.884
# 81  23499.720  1756.370  1503.472  4950.528  293.752  1994.186   603.244
# 82  27075.715   237.787   414.418  6071.487  670.498  1723.033   460.246
# 83  25782.137   851.590  1345.876  5301.146  234.302  2443.622   887.260
# 84  23462.324  1407.859  2569.796  6488.689  395.961  2169.556  1094.192
#
#       7        8         9      ...     16373    16374    16375     16376  \
# 0   149.570   44.134   527.588  ...   201.504  130.509   40.299   246.934
# 1   117.612   42.127   421.173  ...  1106.225  232.559   89.161   537.229
# 2    93.095   28.982   494.550  ...   635.171  286.048   61.337   926.042
# 3    80.668   71.308  1010.702  ...   292.580   86.146   95.435   801.629
# 4   248.498   67.267   945.524  ...   450.114  522.818  105.287   133.524
# ..      ...      ...       ...  ...       ...      ...      ...       ...
# 80   88.991   30.365   375.230  ...   424.362   64.379   30.708   927.304
# 81  806.646   32.505   303.930  ...   638.237   69.953   41.823  1405.234
# 82   62.021  100.764   286.953  ...   206.852   88.040   85.819    57.012
# 83  620.340  347.230   154.523  ...   789.899  141.794   68.175   763.070
# 84  350.590  822.722   393.175  ...   579.102   82.243   28.899   629.547
#
#        16377    16378    16379    16380    16381    16382
# 0    441.796   99.234  187.045   37.691   44.192   95.788
# 1   1054.352  253.680  258.023   79.139  142.184   27.213
# 2    749.070  215.656   62.993   61.992  205.953   77.265
# 3    914.284   75.940  383.597  103.559  197.135  349.095
# 4    887.297  511.111  373.564   55.149   22.576  102.112
# ..       ...      ...      ...      ...      ...      ...
# 80   512.514  354.862   99.011   60.889  180.684  191.753
# 81   732.371  172.231  388.798   61.062   26.805   50.738
# 82   769.279  115.342   91.366   93.376  138.852  136.632
# 83   708.839  158.847   23.393   83.366  151.754   77.744
# 84   740.703  398.025  241.551   77.068   35.906  257.664
#
# [85 rows x 16383 columns]

# %%
import pandas as pd 
y = pd.read_csv(r"C:\Bahar\M.Sc Data Mining\Machine Learning (Oct 2022-Feb 2023)\HW1\Data\GLI-85_target.csv", header=None)
y
# Out:
#     0
# 0   1
# 1   1
# 2   1
# 3   1
# 4   1
# .. ..
# 80  2
# 81  2
# 82  2
# 83  2
# 84  2
#
# [85 rows x 1 columns]

# %% [raw]
# Split datas to 80% train & 20% test

# %%
import numpy as np
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_
# 63  22320.672   677.086   620.380  6475.737  619.227  2788.227  1342.646
# 84  23462.324  1407.859  2569.796  6488.689  395.961  2169.556  1094.192
# 50  37648.332  1874.908  1256.215  5620.608  247.378  3027.899   972.662
#
#       7        8         9      ...     16373    16374   16375     16376  \
# 6   243.245   60.274  1086.237  ...   695.531   90.413  33.602  1205.850
# 55  213.908   35.828   610.905  ...   543.141  187.552  69.253  1187.513
# 14  379.977   30.675   417.519  ...   263.913  559.269  19.709   431.713
# 83  620.340  347.230   154.523  ...   789.899  141.794  68.175   763.070
# 44  149.603   58.074   691.173  ...  1089.810  139.652  63.952   428.492
# 73  150.007  156.945   493.851  ...   394.280   82.801  41.205   407.304
# 75  594.370  121.998   308.285  ...   293.547   75.520  27.400  1305.537
# 43  532.881  266.612   359.044  ...   595.383   82.803  46.804  1084.720
# 19  464.938   33.698   599.192  ...   371.824   73.189  55.735   651.923
# 59  398.354  103.743   671.964  ...   372.707   69.749  63.814   650.199
# 5   280.877   33.587   898.889  ...  1080.645  132.435  51.347   575.813
# 45  254.805   55.731   311.596  ...   200.069   78.863  67.852   642.003
# 66  408.272  159.101   428.918  ...   324.234   81.407  42.908  1352.407
# 8    62.123  176.803   362.022  ...   776.494  336.155  59.798   402.956
# 63  135.345   38.628   646.558  ...   633.457  115.990  49.302   362.051
# 84  350.590  822.722   393.175  ...   579.102   82.243  28.899   629.547
# 50  874.137   46.022   330.649  ...   396.882   58.499  25.069  1061.277
#
#        16377    16378    16379    16380    16381    16382
# 6    561.474  355.277  251.679   86.568   64.037  519.263
# 55   871.455  360.212  353.826   56.132  328.968  106.284
# 14   444.279  251.048  287.379   82.003  197.274  377.783
# 83   708.839  158.847   23.393   83.366  151.754   77.744
# 44   756.203  392.834  425.012  143.497  182.107  288.471
# 73   615.911  357.960  225.117  138.656  201.031  114.716
# 75   563.111  369.714  554.470   57.208  159.724  106.762
# 43   876.582  305.839  340.888   67.358  131.294  251.145
# 19   804.450  203.456  289.203   68.315  182.504  282.478
# 59   908.067  275.110  408.520  106.450   31.805  356.868
# 5   1343.862  311.239  118.373   71.942   86.532  240.523
# 45   356.064  279.790  365.184   57.683  217.224  111.466
# 66   572.793  550.489  495.016  395.042   33.820  126.987
# 8    712.576  207.342  113.376   66.105   56.940  114.636
# 63   937.615  505.070  329.497   89.290   48.393  189.926
# 84   740.703  398.025  241.551   77.068   35.906  257.664
# 50   936.046  429.534  275.795  112.683   33.212  132.351
#
# [17 rows x 16383 columns]

# %% [raw]
# A. Linear regression

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train, y_train)

# %%
reg.score(X_train, y_train)
# Out:
# 1.0

# %%
reg.coef_
# Out:
# array([[ 2.70165638e-07, -4.80079563e-09,  1.18122073e-07, ...,
#          9.77359090e-10,  1.96878999e-09,  1.65692229e-08]])

# %%
reg.intercept_
# Out:
# array([1.00853782])

# %%
y_pred = reg.predict(X_train)

# %%
import numpy as np
import sklearn.metrics as sm
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
MSE1 = sm.mean_squared_error(y_train, y_pred)
MAE1 = sm.mean_absolute_error(y_train, y_pred)

# %%
print("Mean absolute error Train =", round(mean_absolute_error(y_train, y_pred), 2))
print("Mean squared error Train =", round(mean_squared_error(y_train, y_pred), 2))
# Out:
# Mean absolute error Train = 0.0
# Mean squared error Train = 0.0

# %%
y_test_pred = reg.predict(X_test)
MSE2 = round(sm.mean_squared_error(y_test, y_test_pred),2)
MAE2 = round(sm.mean_absolute_error(y_test, y_test_pred),2)

# %%
print("Mean absolute error Test=", round(sm.mean_absolute_error(y_test, y_test_pred), 2)) 
print("Mean squared error Test=", round(sm.mean_squared_error(y_test, y_test_pred), 2)) 
print('method is Linear regression  by %s  accuracy for test data'%((1-MSE2)*100))
print('method is Linear regression  by %s  accuracy for test data'%((1-MAE2)*100))
# Out:
# Mean absolute error Test= 0.28
# Mean squared error Test= 0.13
# method is Linear regression  by 87.0  accuracy for test data
# method is Linear regression  by 72.0  accuracy for test data

# %% [raw]
# B-1. Lasso

# %%
import numpy as np
from sklearn import linear_model
reg = linear_model.Lasso (alpha = 0.5)
reg.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.295e-03, tolerance: 1.451e-03
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=0.5)

# %%
y_pred = reg.predict(X_test)

# %%
y_pred
# Out:
# array([1.82624135, 1.56364509, 1.68458515, 2.54831142, 1.46535448,
#        2.23330896, 1.87549185, 1.9187299 , 1.5488923 , 1.52557667,
#        1.02643946, 1.97837488, 1.67385946, 0.99780937, 1.26627886,
#        1.8698328 , 1.93222431])

# %%
import math
L = []
for i in y_pred:
    L.append((math.floor(i))) 
y_pred_lasso = np.expand_dims(L, -1)

# %%
from sklearn.metrics import accuracy_score
Ac_Sc_L = accuracy_score(y_test, y_pred_lasso)

# %%
print('method is Lasso by %s  accuracy for test data'%((1-Ac_Sc_L)*100))
# Out:
# method is Lasso by 64.70588235294117  accuracy for test data

# %% [raw]
# B-2. Ridge regression

# %%
import numpy as np
from sklearn import linear_model
reg = linear_model.Ridge (alpha = 0.5)
reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.5)

# %%
reg.coef_
# Out:
# array([[ 2.71112293e-07, -4.68774007e-09,  1.18065449e-07, ...,
#          9.77232429e-10,  1.96688114e-09,  1.65691010e-08]])

# %%
reg.intercept_
# Out:
# array([1.0084713])

# %%
y_pred = reg.predict(X_test)

# %%
y_pred
# Out:
# array([[1.27085162],
#        [1.63503518],
#        [1.83361552],
#        [2.36979636],
#        [1.54960591],
#        [2.00161716],
#        [1.98429377],
#        [1.84824864],
#        [1.23763223],
#        [1.62156723],
#        [1.00235034],
#        [1.84645717],
#        [1.59550151],
#        [1.21225451],
#        [1.30655684],
#        [1.89838947],
#        [2.08311623]])

# %%
import math
L = []
for i in y_pred:
    L.append((math.floor(i))) 
y_pred_ridge = np.expand_dims(L, -1)

# %%
from sklearn.metrics import accuracy_score
Ac_Sc_R = accuracy_score(y_test, y_pred_ridge)

# %%
print('method is Ridge regression by %s  accuracy for test data'%((1-Ac_Sc_R)*100))
# Out:
# method is Ridge regression by 52.94117647058824  accuracy for test data

# %% [raw]
# C. Logistic regression

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state = 777).fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
clf.classes_
# Out:
# array([1, 2], dtype=int64)

# %%
clf.intercept_
# Out:
# array([-6.69803197e-11])

# %%
clf.coef_
# Out:
# array([[ 1.22751851e-05, -5.08769489e-07,  7.76799823e-06, ...,
#         -1.37011517e-08,  1.60166496e-07,  3.03216857e-07]])

# %%
clf.score(X_train, y_train)
# Out:
# 1.0

# %%
clf.score(X_test, y_test)
# Out:
# 0.8235294117647058

# %%
y_pred = clf.predict(X_test)

# %%
y_pred
# Out:
# array([1, 2, 2, 2, 1, 2, 2, 2, 1, 2, 1, 2, 2, 1, 1, 2, 2], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
Ac_Sc = accuracy_score(y_test, y_pred)

# %%
print('method is Logistic regression  by %s  accuracy for test data'%((1-Ac_Sc)*100))
# Out:
# method is Logistic regression  by 17.647058823529417  accuracy for test data

# %%
import numpy as np
import sklearn.metrics as sm
from sklearn.metrics import classification_report, confusion_matrix
classification_report(y_test, y_pred, labels = [1, 2])
# Out:
# '              precision    recall  f1-score   support\n\n           1       0.67      0.80      0.73         5\n           2       0.91      0.83      0.87        12\n\n    accuracy                           0.82        17\n   macro avg       0.79      0.82      0.80        17\nweighted avg       0.84      0.82      0.83        17\n'
